# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup
from google.colab import files , drive
# drive.mount('/gdrive')
# files.upload()

# %%
records=[]

page_num =0
while True:

    record = requests.get(f"https://wuzzuf.net/search/jobs/?a=hpb&q=python&start={page_num}")



    src =record.content 

    soup = BeautifulSoup(src,"lxml")


    page_limit = int(soup.find("strong").text)

    if(page_num > page_limit//15):
       print("page terminate")
       break
    job_titles = soup.find_all("h2",{"class":"css-m604qf"})
    company_names = soup.find_all("a",{"class":"css-17s97q8"})
    loacations = soup.find_all("span",{"class":"css-5wys0k"})
    job_types = soup.find_all("span",{"class":"css-1ve4b75 eoyjyou0"})


    for i in range(len(job_titles)):
        job_title=job_titles[i].a.text.strip()
        company_name=company_names[i].text.strip()
        loacation=loacations[i].text.strip()
        job_type=job_types[i].text.strip()
        records.append((job_title,company_name,loacation,job_type))

    page_num +=1
    






df = pd.DataFrame(records, columns=['job_titles', 'company_names', 'loacations', 'job_type'])  

with open("wuzzaf.csv","w") as f:
     df.to_csv(f) 

files.download("wuzzaf.csv")
df.head(15)
# Out:
# page terminate
#                                           job_titles  \
# 0                            Senior Python Developer
# 1                           Python Backend Developer
# 2                  Senior Software Engineer - Python
# 3              Python Back-End Developer (Part-Time)
# 4                                   Python Developer
# 5                    Flask Python Backend Developer.
# 6           Senior Backend Developer (Python/Django)
# 7                    Backend Developer (Python/Ruby)
# 8                       Senior Python Linux Engineer
# 9                            Senior Python Developer
# 10  Software Engineer - Backend Development (Python)
# 11                                  Python Developer
# 12          Software QA/Automation Engineer [Python]
# 13                                  Python Developer
# 14       Senior Quality Automation Engineer [Python]
#
#                       company_names                   loacations  \
# 0   SURE International Technology -                 Cairo, Egypt
# 1                    Salney, Inc. -                 Cairo, Egypt
# 2                Paymob Solutions -          Maadi, Cairo, Egypt
# 3                    Snuggs Egypt -      New Cairo, Cairo, Egypt
# 4                          Andela -                 Cairo, Egypt
# 5              Virtual Worker Now -                 Cairo, Egypt
# 6                          Valify -          Maadi, Cairo, Egypt
# 7                 Nile University -    Sheikh Zayed, Giza, Egypt
# 8          El-Sewedy Electrometer -  6th of October, Giza, Egypt
# 9                      FlairsTech -                 Cairo, Egypt
# 10              Synapse Analytics -                 Cairo, Egypt
# 11                     FlairsTech -                 Cairo, Egypt
# 12                     FlairsTech -                 Cairo, Egypt
# 13                 Anspire Agency -      New Cairo, Cairo, Egypt
# 14                     FlairsTech -          Maadi, Cairo, Egypt
#
#                job_type
# 0             Full Time
# 1             Full Time
# 2             Full Time
# 3        Work From Home
# 4             Part Time
# 5   Freelance / Project
# 6        Work From Home
# 7             Full Time
# 8   Freelance / Project
# 9        Work From Home
# 10            Full Time
# 11       Work From Home
# 12            Full Time
# 13            Full Time
# 14            Full Time
